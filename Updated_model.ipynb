# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/McKenzyPG/game_level_gen_with_rnn/blob/master/Updated_model.ipynb)

# %%
# !pip install -q textgenrnn
from google.colab import files
from textgenrnn import textgenrnn
import os
# Out:
# Using TensorFlow backend.

# %%
uploaded = files.upload()
all_files = [(name, os.path.getmtime(name)) for name in os.listdir()]
latest_file = sorted(all_files, key=lambda x: -x[1])[0][0]
# Out:
#      <input type="file" id="files-08205cbf-9881-4f92-8ec5-ad268100efcc" name="files[]" multiple disabled />
#      <output id="result-08205cbf-9881-4f92-8ec5-ad268100efcc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving level1.txt to level1.txt

# %%
textgen = textgenrnn()

# %%
textgen.reset()

# %%
textgen.train_from_file(latest_file,new_model=True,
                        rnn_bidirectional=True,
                        rnn_size=128,
                        dim_embeddings=100,
                        num_epochs=100)
# Out:
# 23 texts collected.
# Training new model w/ 2-layer, 128-cell Bidirectional LSTMs
# Training on 598 character sequences.
# Epoch 1/100
# 4/4 [==============================] - 6s 2s/step - loss: 2.4980
# ####################
# Temperature: 0.2
# ####################
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
#
#
#
#
#
#
# ####################
# Temperature: 1.0
# ####################
#                                                                                                            *                                                               *
#
#     *                                                                                                                                                                                                                                                                                    *
#
#
#
# Epoch 2/100
# 4/4 [==============================] - 4s 907ms/step - loss: 2.6214
# ####################
# ...

# %%
print(textgen.model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input (InputLayer)              (None, 40)           0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 40, 100)      800         input[0][0]
# __________________________________________________________________________________________________
# rnn_1 (Bidirectional)           (None, 40, 256)      234496      embedding[0][0]
# __________________________________________________________________________________________________
# rnn_2 (Bidirectional)           (None, 40, 256)      394240      rnn_1[0][0]
# __________________________________________________________________________________________________
# rnn_concat (Concatenate)        (None, 40, 612)      0           embedding[0][0]
# ...

# %%
textgen.generate(24, temperature = 1.5)
# Out:
# *###       *#*       ###*
#
# *************************
#
# * A    ## ###       ###*
#
# *##     *  *#*    ##   B*
#
# *###       * *       ###*
#
# *          * *          *
#
# *  A##A#*  #     ##  #*
#
# *###   #####    **##  B*
#
# *###      **#**      ###*
#
# *          * *       H  *
#
# *## #      #####    #  #*
#
# *H H       *            *
#
# *H  ******           *
#
# *## *
#
# *   ##         A#####  H*
#
# *   ##             ##   *
#
# *   ##     ###     ##   *
#
# *###       * *          **
#
# *   ##    **#**    ##   * *
#
# *************************
#
# *# ##     ### ##    *
#
# *   ##     ###     ##   *
#
# *   ##    #####    ##  B*
#
# *H  *     ***

# %%
# !ls
# Out:
# level1.txt   textgenrnn_config.json  textgenrnn_weights.hdf5
# sample_data  textgenrnn_vocab.json

# %%
# !ls
# Out:
# level1.txt   textgenrnn_config.json  textgenrnn_weights.hdf5
# sample_data  textgenrnn_vocab.json

# %%
files.download('textgenrnn_config.json')

# %%
files.download('textgenrnn_weights.json')

# %%
files.download('textgenrnn_vocab.json')

# %%
test = textgenrnn(weights_path = 'textgenrnn_weights.hdf5', vocab_path = 'textgenrnn_vocab.json',  config_path = 'textgenrnn_config.json')

# %%
test.generate(24, temperature = 1.5)
# Out:
# *H#A#     ####*#    *  *
#
# *          *#*          *
#
# *## ##    * **    *  * *
#
# *##  ##   ########   H#*
#
# *          *H *         *
#
# * *  ##    *#*     ##  B*
#
# * A##     *
#
# *   ##       B#        *B
#
# *H A###    ######    ####*
#
# *### #  ****####***   #*
#
# *   ##     ###B     ##  *
#
# *# ********#####*A***** #*
#
# *   *#     ####    ###  *
#
# *#********#####******* ####*
#
# *# #      #*#*#   *   # *
#
# *          * *
#
# *# ##     ######    *  #*
#
# *##*********####* ***** ##*
#
# **A##B     ##**#    ##B#*
#
# *  *        *#*        H*
#
# *###       * *       ###*
#
# *## # ****#####****#H* ## ##*
#
# *H ###    #######    ###  *
#
# *   ***# *****   ***** *  *
