# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/McKenzyPG/game_level_gen_with_rnn/blob/master/rnn_to_gen_game_lvls.ipynb)

# %%
# !pip install -q textgenrnn
from google.colab import files
from textgenrnn import textgenrnn
import os
# Out:
# Using TensorFlow backend.

# %%
uploaded = files.upload()
all_files = [(name, os.path.getmtime(name)) for name in os.listdir()]
latest_file = sorted(all_files, key=lambda x: -x[1])[0][0]
# Out:
#      <input type="file" id="files-7fa9ca1e-6b2d-411b-8318-4e964d0290c5" name="files[]" multiple disabled />
#      <output id="result-7fa9ca1e-6b2d-411b-8318-4e964d0290c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving map.txt to map.txt

# %%
textgen.reset()

# %%
textgen.train_from_file(latest_file,new_model=True,
                        rnn_bidirectional=True,
                        rnn_size=128,
                        dim_embeddings=100,
                        num_epochs=1000)
# Out:
# 23 texts collected.
# Training new model w/ 2-layer, 128-cell Bidirectional LSTMs
# Training on 598 character sequences.
# Epoch 1/1000
# 4/4 [==============================] - 8s 2s/step - loss: 2.9624
# ####################
# Temperature: 0.2
# ####################
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
#
#
#
#
#
#
# ####################
# Temperature: 1.0
# ####################
#
#
#
#
#
#
# Epoch 2/1000
# 4/4 [==============================] - 4s 998ms/step - loss: 2.0197
# ####################
# Temperature: 0.2
# ####################
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
#                                                                                   #            *                          *
#
#  *  *
#
#
#
# ####################
# Temperature: 1.0
# ####################
#     *
#
#          *
#
# *  *
#
# Epoch 3/1000
# 4/4 [==============================] - 4s 953ms/step - loss: 0.6831
# ...

# %%
print(textgen.model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input (InputLayer)              (None, 40)           0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 40, 100)      700         input[0][0]
# __________________________________________________________________________________________________
# rnn_1 (Bidirectional)           (None, 40, 256)      234496      embedding[0][0]
# __________________________________________________________________________________________________
# rnn_2 (Bidirectional)           (None, 40, 256)      394240      rnn_1[0][0]
# __________________________________________________________________________________________________
# rnn_concat (Concatenate)        (None, 40, 612)      0           embedding[0][0]
# ...

# %%
textgen.generate_samples(10)
# Out:
# ####################
# Temperature: 0.2
# ####################
# *                       *
#
# *                       *
#
# *                       *
#
# *                       *
#
# *                       *
#
# *                       *
#
# *                       *
#
# *                       *
#
# *    #                  *
#
# *                       *
#
# ####################
# Temperature: 0.5
# ####################
# *    #                  *
#
# *                       *
#
# *                       *
#
# *    #                  *
#
# *                       *
#
# *                       *
#
# *                       *
#
# *                       *
#
# *                       *
#
# *                       *
#
# ####################
# Temperature: 1.0
# ####################
# *##########     ####### *
#
# *    #                  *
#
# *                       *
#
# *  ##########           *
#
# *    ##############     *
#
# *                       *
#
# ...

# %%
textgen.generate(24, temperature = 3.5)
# Out:
# *  A #              B  *
#
# *      #   ***          *
#
# *************************
#
# *      B                *
#
# *  #######B             *
#
# *
#
# *  #####     ***    A  A*
#
# *  A #      #      #   *
#
# *##########     ####### *
#
# *********#******* **A****
#
# *    A #   A***#A####### *
#
# #                     *
#
# *  #######**  ***       *
#
# *###########B          *
#
# #B   ###########B      *
#
# *  * B                  *
#
# *  A #                  *
#
# *      B                *
#
# *                       *
#
# *##########     ####### *
#
# * **# #          B     # *
#
# *    A***         **     *
#
# *  A #    #    #**###### *
#
# *  A #              #   *

# %%
textgen.generate_to_file('textgenrnn_maps.txt', n=5)

# %%
!-ls -lha
# Out:
# /bin/bash: - : invalid option
# Usage:	/bin/bash [GNU long option] [option] ...
# 	/bin/bash [GNU long option] [option] script-file ...
# GNU long options:
# 	--debug
# 	--debugger
# 	--dump-po-strings
# 	--dump-strings
# 	--help
# 	--init-file
# 	--login
# 	--noediting
# 	--noprofile
# 	--norc
# 	--posix
# 	--rcfile
# 	--restricted
# 	--verbose
# 	--version
# Shell options:
# 	-ilrsD or -c command or -O shopt_option		(invocation only)
# 	-abefhkmnptuvxBCHP or -o option
